# %%
# %pip install -U leafmap
# Out:
# ...
#   Obtaining dependency information for leafmap from https://files.pythonhosted.org/packages/20/b2/f61e33dd661014cfd2de19fe813c96d4d030dd4ad4899c01c1f83c58ee46/leafmap-0.29.3-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for bqplot from https://files.pythonhosted.org/packages/90/2c/e448c4def923fe67dc21f5641f930c26cc0f649a5a5a19aedee8a6be6a91/bqplot-0.12.42-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geojson from https://files.pythonhosted.org/packages/8e/1b/4f57660aa148d3e3043d048b7e1ab87dfeb85204d0fdb5b4e19c08202162/geojson-3.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for ipyevents from https://files.pythonhosted.org/packages/af/49/5692d363a82838282f5c33a787922f07115d7ba4b452391e51db95c9d247/ipyevents-2.0.2-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import leafmap

# %%
img1 = "brazil_map_1.png"
img2 = "brazil_map_2.png"

# %%
leafmap.image_comparison(
    img1,
    img2,
    label1='Brazil 2022',
    label2='Brazil 2012',
    starting_position=50,
    out_html='brazil_image_comparison.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 668; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Brazil 2022',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Brazil 2012',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
#         </head>
# ...
